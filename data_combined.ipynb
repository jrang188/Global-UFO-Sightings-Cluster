# %%
import pandas as pd
import os

# %%
#read the path 
file_path = "C:cmpt353project/ufo_data/"

# %%
# list all the files from the directory
file_list = os.listdir(file_path)

# %%
file_list
# Out:
# ['202001.csv',
#  '202002.csv',
#  '202003.csv',
#  '202004.csv',
#  '202005.csv',
#  '202006.csv',
#  '202007.csv',
#  '202008.csv',
#  '202009.csv',
#  '202010.csv',
#  '202011.csv',
#  '202012.csv',
#  '202101.csv',
#  '202102.csv',
#  '202103.csv',
#  '202104.csv',
#  '202105.csv',
#  '202106.csv',
#  '202107.csv',
#  '202108.csv',
#  '202109.csv',
#  '202110.csv',
#  '202111.csv',
#  '202112.csv',
#  '202201.csv',
#  '202202.csv',
#  '202203.csv',
#  '202204.csv',
#  '202205.csv',
#  '202206.csv',
#  '202207.csv',
#  '202208.csv',
#  '202209.csv',
#  '202210.csv']

# %%
df = pd.concat([pd.read_csv("ufo_data/" + f) for f in file_list], ignore_index=True)

# %%
df
# Out:
#          Date / Time            City State Country    Shape  \
# 0      1/31/20 21:30        Prospect    OR     USA    Light
# 1      1/31/20 19:57    Arizona City    AZ     USA  Unknown
# 2      1/31/20 19:56    Arizona City    AZ     USA  Unknown
# 3      1/31/20 19:30     Sevierville    TN     USA     Oval
# 4      1/31/20 18:45       Cornelius    OR     USA      NaN
# ...              ...             ...   ...     ...      ...
# 14441  10/1/22 15:34      Huntsville    AL     USA    Cigar
# 14442  10/1/22 11:50     Gulf breeze    FL     USA   Circle
# 14443  10/1/22 09:52  Redwood valley    CA     USA    Other
# 14444  10/1/22 04:30       Bountiful    UT     USA    Light
# 14445  10/1/22 03:05        Columbus    MS     USA    Light
#
#                       Duration  \
# 0                    30 minute
# 1                         2:55
# 2                            2
# 3                  3-5 minutes
# 4                          NaN
# ...                        ...
# ...

# %%
# append all files together
df.to_csv('data_combined.csv')
