# %%
import pandas as pd 
import numpy as np

# %%
#Read csv file into dataframe 
df = pd.read_csv('ufo_data/202001.csv')
df
# Out:
#        Date / Time            City State Country     Shape     Duration  \
# 0    1/31/20 21:30        Prospect    OR     USA     Light    30 minute
# 1    1/31/20 19:57    Arizona City    AZ     USA   Unknown         2:55
# 2    1/31/20 19:56    Arizona City    AZ     USA   Unknown            2
# 3    1/31/20 19:30     Sevierville    TN     USA      Oval  3-5 minutes
# 4    1/31/20 18:45       Cornelius    OR     USA       NaN          NaN
# ..             ...             ...   ...     ...       ...          ...
# 627   1/1/20 00:00       El Centro    CA     USA    Circle    3 minutes
# 628   1/1/20 00:00     Bakersfield    CA     USA    Circle    5 minutes
# 629   1/1/20 00:00           Brick    NJ     USA    Circle    2 minutes
# 630         1/1/20  St. Petersburg    FL     USA  Triangle         3:00
# 631         1/1/20     San Antonio    TX     USA      Oval    5 minutes
#
#                                                Summary   Posted  Images
# ...

# %%
#drop the column 
to_drop = ['Images','Posted']
df.drop(to_drop, inplace = True, axis = 1)
df.head()
# Out:
#      Date / Time          City State Country    Shape     Duration  \
# 0  1/31/20 21:30      Prospect    OR     USA    Light    30 minute
# 1  1/31/20 19:57  Arizona City    AZ     USA  Unknown         2:55
# 2  1/31/20 19:56  Arizona City    AZ     USA  Unknown            2
# 3  1/31/20 19:30   Sevierville    TN     USA     Oval  3-5 minutes
# 4  1/31/20 18:45     Cornelius    OR     USA      NaN          NaN
#
#                                              Summary   Posted
# 0  1.31.2020 Approximately 9:30-10 While driving ...   2/7/20
# 1            Blinking lights tha pull away and tilt.   5/1/20
# 2    Blinking unexplained lights that tilt and move.  2/25/20
# 3  This is twice in one week I've seen this. Roun...   2/7/20
# 4  5 bright orange lights traveling in drunken ma...   2/7/20

# %%
#Group by Country and 
gk = df.groupby(['Country'])['Country'].count()
print(gk)

#There are
# Out:
# Country         State
# Canada          AB            6
#                 BC            7
#                 MB            1
#                 NB            1
#                 ON            6
#                 QC            1
#                 SK            1
# India           Karnataka     1
# USA             AK            3
#                 AL            9
#                 AR           13
#                 AZ           16
#                 CA           54
#                 CO           25
#                 CT            5
#                 DE            5
#                 FL           58
#                 GA           14
#                 HI            6
#                 IA           13
#                 ID            7
#                 IL            4
#                 IN           24
#                 KS            5
#                 KY            5
#                 LA            6
#                 MA           13
#                 MD            5
# ...
